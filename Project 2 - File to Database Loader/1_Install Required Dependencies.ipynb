# %%
# Required for Notebook to use SQL Magic
# Facilitates to run queries from Notebooks 
# without using Python Code
# !pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipython-sql
#   Using cached ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: ipython in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython-sql) (8.36.0)
# Collecting ipython-genutils
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting sqlparse
#   Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: six in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython-sql) (1.17.0)
# Collecting prettytable
#   Using cached prettytable-3.16.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython-sql) (2.0.42)
# Requirement already satisfied: greenlet>=1 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.13.2)
# Requirement already satisfied: colorama in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: decorator in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (1.3.0)
# Requirement already satisfied: matplotlib-inline in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from ipython->ipython-sql) (3.0.51)
# Requirement already satisfied: wcwidth in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from stack_data->ipython->ipython-sql) (2.2.0)
# Requirement already satisfied: pure-eval in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from stack_data->ipython->ipython-sql) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Installing collected packages: ipython-genutils, sqlparse, prettytable, ipython-sql
# Successfully installed ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.16.0 sqlparse-0.5.3
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\U1119902\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psycopg2 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (2.9.10)
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Native Postgres Library to connect to Posgres Database Server
# !pip install psycopg2-binary==2.9.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting psycopg2-binary==2.9.4
#   Using cached psycopg2_binary-2.9.4-cp310-cp310-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.4
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# SQLAlchemy is ORM and needs native database libraries (psycopg2)
# Pandas internally uses SQL Alchemy to connect to database
# !pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sqlalchemy in c:\users\u1119902\appdata\roaming\python\python310\site-packages (2.0.42)
# Requirement already satisfied: greenlet>=1 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from sqlalchemy) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\u1119902\appdata\roaming\python\python310\site-packages (from sqlalchemy) (4.13.2)
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
