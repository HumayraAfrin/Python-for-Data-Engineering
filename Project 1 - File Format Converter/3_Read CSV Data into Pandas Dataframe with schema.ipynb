# %%
import glob as glb

# %%
src_file_name = glb.glob('Data\Retail_DB\*')
src_file_name
# Out:
# ['Data\\Retail_DB\\categories.txt',
#  'Data\\Retail_DB\\customers.txt',
#  'Data\\Retail_DB\\departments.txt',
#  'Data\\Retail_DB\\orders.txt',
#  'Data\\Retail_DB\\orders_json',
#  'Data\\Retail_DB\\order_items.txt',
#  'Data\\Retail_DB\\products.txt',
#  'Data\\Retail_DB\\schemas.json']

# %% [markdown]
# In case of having both kind of slash in a string, it's difficult to the get char separately using a single split function. To avoid this challange, we can use Regular expression (re).

# %%
s = 's/a\\b\\c'
s.split('/')
# Out:
# ['s', 'a\\b\\c']

# %%
s.split('\\')
# Out:
# ['s/a', 'b', 'c']

# %%
import re

# %%
re.split('[/\\\]', s)
# Out:
# ['s', 'a', 'b', 'c']

# %%
for filename in src_file_name:
    print(filename.split('\\'))
# Out:
# ['Data', 'Retail_DB', 'categories.txt']
# ['Data', 'Retail_DB', 'customers.txt']
# ['Data', 'Retail_DB', 'departments.txt']
# ['Data', 'Retail_DB', 'orders.txt']
# ['Data', 'Retail_DB', 'orders_json']
# ['Data', 'Retail_DB', 'order_items.txt']
# ['Data', 'Retail_DB', 'products.txt']
# ['Data', 'Retail_DB', 'schemas.json']

# %%
src_file_name[1]
# Out:
# 'Data\\Retail_DB\\customers.txt'

# %%
file = re.split('[/\\\]', src_file_name[1])
file
# Out:
# ['Data', 'Retail_DB', 'customers.txt']

# %%
ds_name = file[2]
ds_name
# Out:
# 'customers.txt'

# %%
for file in src_file_names:
    print(f'Processing {file}')
    file_path_list = re.split('[/\\\]', file)
    ds_name = file_path_list[-2]
    columns = get_column_names(schemas, ds_name)
    df = pd.read_csv(file, names=columns)
    print(f'Shape of {ds_name} is {df.shape}')
