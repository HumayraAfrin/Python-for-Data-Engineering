# %%
import glob as glb
import re

# %%
src_file_name = glb.glob('Data\Retail_DB\*')
src_file_name
# Out:
# ['Data\\Retail_DB\\categories.txt',
#  'Data\\Retail_DB\\customers.txt',
#  'Data\\Retail_DB\\departments.txt',
#  'Data\\Retail_DB\\orders.json',
#  'Data\\Retail_DB\\orders.txt',
#  'Data\\Retail_DB\\order_items.txt',
#  'Data\\Retail_DB\\products.txt',
#  'Data\\Retail_DB\\schemas.json']

# %%
for file in src_file_name:
    file_path_list = re.split('[/\\\.]', file)
    print(file_path_list)
# Out:
# ['Data', 'Retail_DB', 'categories', 'txt']
# ['Data', 'Retail_DB', 'customers', 'txt']
# ['Data', 'Retail_DB', 'departments', 'txt']
# ['Data', 'Retail_DB', 'orders', 'json']
# ['Data', 'Retail_DB', 'orders', 'txt']
# ['Data', 'Retail_DB', 'order_items', 'txt']
# ['Data', 'Retail_DB', 'products', 'txt']
# ['Data', 'Retail_DB', 'schemas', 'json']

# %%
target_base_dir = 'Data\Retail_DB_json'
target_base_dir
# Out:
# 'Data\\Retail_DB_json'

# %%
ds_name = file_path_list[-2]
ds_name
# Out:
# 'schemas'

# %%
for file in src_file_name:
    file_path_list = re.split('[/\\\.]', file)
    ds_name = file_path_list[-2]
    json_file_path = f'{target_base_dir}\{ds_name}'
    print(json_file_path)
# Out:
# Data\Retail_DB_json\categories
# Data\Retail_DB_json\customers
# Data\Retail_DB_json\departments
# Data\Retail_DB_json\orders
# Data\Retail_DB_json\orders
# Data\Retail_DB_json\order_items
# Data\Retail_DB_json\products
# Data\Retail_DB_json\schemas
